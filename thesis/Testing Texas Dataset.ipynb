# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cd dataverse_files
# Out:
# /Users/piperfrances/Thesis/dataverse_files

# %%
# https://dataverse.tdl.org/dataset.xhtml?persistentId=doi:10.18738/T8/LG5E1W
df = pd.read_csv("ut3000.lattice.public.csv")

# %%
df
# Out:
#       Unnamed: 0       pid  acc.mag.rmssd   loc.var   ent.pls  unlocked.dur  \
# 0              1  11i3mr4n       0.072312  0.073420  0.190404    589.691428
# 1              2  11jbbat5       0.103602  0.220368  0.283593    891.479225
# 2              3  121f7uao       0.167806  0.094619  0.185173    346.847529
# 3              4  13al1wr7       0.169629  0.012031  0.201228   1019.681240
# 4              5  158hmxr8       0.115221  0.014936  0.164134    384.406708
# ...          ...       ...            ...       ...       ...           ...
# 1410        1411  sk5qjq6i       0.215875  0.004950  0.183851    415.747120
# 1411        1412  sm5uxkzd       0.128686  0.004211  0.231172    354.859797
# 1412        1413  smike3x6       0.157453  0.043180  0.118010    437.368220
# 1413        1414  so63umwm       0.138976  0.015454  0.259694    976.586354
# 1414        1415  so6bcyx9       0.092334  0.119583  0.103416    542.040974
#
#       mean.sadness  sd.sadness  num.entries
# ...

# %%
len(df.pid.unique())
# Out:
# 1415

# %%
matrix = np.corrcoef(df["loc.var"], df["sd.sadness"])

# %%
print("Correlation Matrix")
df.corr()
# Out:
# Correlation Matrix
# /var/folders/j4/ddyplt452md2_lm_qkykk0br0000gq/T/ipykernel_54882/435553386.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Unnamed: 0  acc.mag.rmssd   loc.var   ent.pls  unlocked.dur  \
# Unnamed: 0       1.000000       0.004924 -0.021587  0.071955      0.041125
# acc.mag.rmssd    0.004924       1.000000 -0.015464 -0.025454     -0.038220
# loc.var         -0.021587      -0.015464  1.000000  0.072092      0.046326
# ent.pls          0.071955      -0.025454  0.072092  1.000000      0.278380
# unlocked.dur     0.041125      -0.038220  0.046326  0.278380      1.000000
# mean.sadness     0.022202      -0.009795 -0.037087 -0.024287      0.041263
# sd.sadness       0.002527       0.004568  0.009976 -0.007998      0.017374
# ...

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error

x_train, x_test, y_train, y_test = train_test_split(df['loc.var'], df['sd.sadness'], test_size=0.2, train_size=0.8, random_state = 0)

# %%
#oversample = SMOTE()
x_str = "loc.var"
y_str = "mean.sadness"

x = df[x_str].to_numpy().reshape(-1, 1)
y = df[y_str].to_numpy().reshape(-1, 1)
#x, y = oversample.fit_resample(x, y)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, train_size=0.8, random_state = 0)


linearModel = LinearRegression()
x_train= x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
linearModel.fit(x_train, y_train)
y_pred = linearModel.predict(x_test)
print("Linear Regression model performed on " + x_str + " vs. " + y_str)
print("\nCorrelation Coefficient = " + str(linearModel.coef_))
print("R^2 score = " + str(linearModel.score(x, y)))
print("\nMean Squared Error = " + str(mean_squared_error(y_test, y_pred)))
#print(linearModel.intercept_, linearModel.coef_, linearModel.score(x, y))
# Out:
# Linear Regression model performed on loc.var vs. mean.sadness
#
# Correlation Coefficient = [[-0.13905806]]
# R^2 score = 0.001330210709497015
#
# Mean Squared Error = 0.34138333794008224

# %%
#oversample = SMOTE()
x_str = "ent.pls"
y_str = "mean.sadness"

x = df[x_str].to_numpy().reshape(-1, 1)
y = df[y_str].to_numpy().reshape(-1, 1)
#x, y = oversample.fit_resample(x, y)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, train_size=0.8, random_state = 0)


linearModel = LinearRegression()
x_train= x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
linearModel.fit(x_train, y_train)
y_pred = linearModel.predict(x_test)
print("Linear Regression model performed on " + x_str + " vs. " + y_str)
print("\nCorrelation Coefficient = " + str(linearModel.coef_))
print("R^2 score = " + str(linearModel.score(x, y)))
print("\nMean Squared Error = " + str(mean_squared_error(y_test, y_pred)))
#print(linearModel.intercept_, linearModel.coef_, linearModel.score(x, y))
# Out:
# Linear Regression model performed on ent.pls vs. mean.sadness
#
# Correlation Coefficient = [[-0.17589596]]
# R^2 score = 0.0004419665582213739
#
# Mean Squared Error = 0.34081979125754536

# %%
# import statsmodels.api as sm
# x = sm.add_constant(x)
# model = sm.OLS(y, x).fit()
# print(model.summary())

# %%
#oversample = SMOTE()
x_str = "unlocked.dur"
y_str = "mean.sadness"

x = df[x_str].to_numpy().reshape(-1, 1)
y = df[y_str].to_numpy().reshape(-1, 1)
#x, y = oversample.fit_resample(x, y)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, train_size=0.8, random_state = 0)


linearModel = LinearRegression()
x_train= x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
linearModel.fit(x_train, y_train)
y_pred = linearModel.predict(x_test)
print("Linear Regression model performed on " + x_str + " vs. " + y_str)
print("\nCorrelation Coefficient = " + str(linearModel.coef_))
print("R^2 score = " + str(linearModel.score(x, y)))
print("\nMean Squared Error = " + str(mean_squared_error(y_test, y_pred)))
#print(linearModel.intercept_, linearModel.coef_, linearModel.score(x, y))
# Out:
# Linear Regression model performed on unlocked.dur vs. mean.sadness
#
# Correlation Coefficient = [[8.23542498e-05]]
# R^2 score = 0.0016894924847401516
#
# Mean Squared Error = 0.3408364298784712

# %%
#oversample = SMOTE()
x_str = "acc.mag.rmssd"
y_str = "mean.sadness"

x = df[x_str].to_numpy().reshape(-1, 1)
y = df[y_str].to_numpy().reshape(-1, 1)
#x, y = oversample.fit_resample(x, y)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, train_size=0.8, random_state = 0)


linearModel = LinearRegression()
x_train= x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
linearModel.fit(x_train, y_train)
y_pred = linearModel.predict(x_test)
print("Linear Regression model performed on " + x_str + " vs. " + y_str)
print("\nCorrelation Coefficient = " + str(linearModel.coef_))
print("R^2 score = " + str(linearModel.score(x, y)))
print("\nMean Squared Error = " + str(mean_squared_error(y_test, y_pred)))
#print(linearModel.intercept_, linearModel.coef_, linearModel.score(x, y))
# Out:
# Linear Regression model performed on acc.mag.rmssd vs. mean.sadness
#
# Correlation Coefficient = [[-0.00113704]]
# R^2 score = 7.946767885191885e-05
#
# Mean Squared Error = 0.34134844699952016
